# %%
# Load extracted texts

with open("extracted_text/model_text.txt", "r") as f:
    model_text = f.read()

with open("extracted_text/student_text.txt", "r") as f:
    student_text = f.read()

print("Files Loaded Successfully ✅")
# Out:
# Files Loaded Successfully ✅

# %%
print("MODEL TEXT PREVIEW:\n")
print(model_text[:500])

print("\n----------------------------\n")

print("STUDENT TEXT PREVIEW:\n")
print(student_text[:500])
# Out:
# MODEL TEXT PREVIEW:
#
# Enroll. No. Sy
#
# MARWADI UNIVERSITY
# Faculty of Technology
# Information and Communication Technology
# ea _ B.Tech SEM: VI Mid 2 Exam April 2024
# Subject: -ArtificialIntelligence(01CT0616) = = TotalMarks:-30
#
# 1. What is Artificial Intelligence?
#
# A) Database. B) Simulation of human intelligence
#
# C) Hardware. D) Network Answer: 2
# 2. What does NLP stand for?
#
# A) Network Layer Protocol B) Natural Language Processing
#
# C) Neural Language Program D) Numeric Logic Processing Answer: _Q-
# 3. What is Machine Lea
#
# ----------------------------
#
# STUDENT TEXT PREVIEW:
#
# Enroll. No.
#
# MARWADI UNIVERSITY
#
# Faculty of Technology
#
# Information and Communication Technology
#
# B.Tech SEM: VI Mid 2 Exam April 2024
# Subject: - Artificial Intelligence (01CT0616) Total Marks:-30
#
# 1. What is Artificial Intelligence?
#
# A) Database. B) Simulation of human intelligence
#
# C) Hardware. D) Network Answer:B
# 2. What does NLP stand for?
#
# A) Network Layer Protocol B) Natural Language Processing
#
# C) Neural Language Program D) Numeric Logic Processing Answer:B
# 3. What is Machine Learning?
#
# A
