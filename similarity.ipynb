# %%
# Load extracted texts

with open("extracted_text/model_text.txt", "r") as f:
    model_text = f.read()

with open("extracted_text/student_text.txt", "r") as f:
    student_text = f.read()

print("Files Loaded Successfully ✅")
# Out:
# Files Loaded Successfully ✅

# %%
print("MODEL TEXT PREVIEW:\n")
print(model_text[:500])

print("\n----------------------------\n")

print("STUDENT TEXT PREVIEW:\n")
print(student_text[:500])
# Out:
# MODEL TEXT PREVIEW:
#
# Enroll. No.
#
# MARWADI UNIVERSITY
# h A VAs H NAAC FOET, MU-FOT
# 3 c a d INFORMATION AND COMMUNICATION TECHNOLOGY
# University
# Marwadi Chandarana Group MU FINAL EXAM
#
# SEMESTER 5 - Winter - Dec-2025
#
# Subject : COMPUTER NETWORKS ( 01CT0503 )
#
# Date : 09-Dec-2025 Time : 2 Hours Total Marks : 60
# Instructions :
# 1. Attempt all questions.
# 2. Make suitable assumptions wherever necessary.
# 3. Figures to the right indicate full marks.
# 4. Do not write/sign/indication/tick mark anything other than Enroll No. at a sp
#
# ----------------------------
#
# STUDENT TEXT PREVIEW:
#
# MARWADI UNIVERSITY
#
# Enrolment No.
#
# 4 Je [stot 13/3 pols} 4] |
#
# 92301733054
# Student's Signature
#
# — a
#
# Supervisor's Name 4
#
# 112273196621
#
# Question
# No.
#
# Total Marks
#
# Obtained
# SIGNATURE OF SUPERVISOR
# Total Marks (Incase of student registered under unfair means)
#
# Rounded
# Total Marks SIGNATURE OF SENIOR SUPERVISOR
# in Words (Incase of student registered under unfair means)
#
# Examiner's Full Name Signature & Date
#
# BARCODE/QR FOR EXAMINER
#
# Marwadi Posie sie luiegt A
# University Sah canna on, | ee ecm eS
# Ma
